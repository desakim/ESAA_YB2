# %% [markdown]
# <a href="https://colab.research.google.com/github/desakim/ESAA_YB2/blob/main/desakim_YB2_6_doit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04-1 데이터 시각화가 필요한 이유

# %%
# 앤스콤 데이터 집합 불러온 후 그래프 그리기
# 1. 앤스콤 데이터 집합 불러오기
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 2. matplotlib 라이브러리로 그래프 그리기
import matplotlib.pyplot as plt

# 3.
dataset_1 = anscombe[anscombe['dataset']=='I']

# 4. 
plt.plot(dataset_1['x'], dataset_1['y'])

# 5. 
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
# 앤스콤 데이터 집합 모두 사용해 그래프 만들기
# 1. 전체 그래프가 위치할 기본 틀 만들기
# 2. 그래프를 그려 넣을 그래프 격자 만들기
# 3. 격자에 그래프 하나씩 추가하기. 왼쪽에서 오른쪽으로 추가됨
# 4. 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그려넣음

# 한 번에 4개의 그래프 그리기
# 1. 데이터셋 열의 값이 1,2,3,4인 것을 불린 추출하여 dataset_1,2,3,4에 저장
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# 2. 그래프 격자가 위치할 기본 틀 만들기
fig = plt.figure()

# 3. add_subplot(그래프 기본 틀의 행 크기, 그래프 기본 틀의 열 크기)
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# 4. 점으로 그래프 표현. fig를 반드시 입력
axes1.plot(dataset_1['x'], dataset_1['y'] , 'o')
axes2.plot(dataset_2['x'], dataset_2['y'] , 'o')
axes3.plot(dataset_3['x'], dataset_3['y'] , 'o')
axes4.plot(dataset_4['x'], dataset_4['y'] , 'o')

fig

# %%
# 5. set_title을 이용하여 그래프 격자에 제목 추가
axes1.set_title("dataset_l")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig

# %%
# 6. suptitle을 이용하여 fig에 제목 추가
fig.suptitle("Anscombe Data")

fig

# %%
# 7. tight_layout을 이용하여 그래프의 레이아웃 조절
fig.tight_layout()

fig

# %% [markdown]
# # 04-2 matplotlib 라이브러리 자유자재로 사용하기

# %%
# 기초 그래프 그리기
# 기초 그래프 그리기 - 히스토그램, 산점도 그래프, 박스 그래프

# 1. tips 데이터 집합을 불러와 tips에 저장하기
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))

# 2. 히스토그램은 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도로 사용, 데이터프레임의 열을 변수라고 부름
# 일변량 그래프는 변수를 하나만 사용해서 그린 그래프

# 3. 기본 틀(fig)를 마련하고 그래프 격자(axes1)를 구성
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# 4. hist를 이용해 히스토그램 만들기. bins를 이용해 x축 간격 조정
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title("Histogram of Total Bill")
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
# 5. 산점도는 변수 2개를 사용해서 만드는 그래프
# 이변량 그래프는 변수 2개를 사용해서 그린 그래프

# 6. 산점도 그래프 그리기
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 7. 박스 그래프는 이산형 변수와 연속형 변수를 함께 사용하는 그래프
# 이산형 변수는 성별과 같이 명확하게 구분되는 값
# 연속형 변수는 tip과 같이 명확하게 셀 수 없는 범위의 값


# 8. boxplot을 이용해 박스 그래프 그리기
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex']=='Female']['tip'],
               tips[tips['sex']=='Male']['tip']],
               labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
# 다변량 그래프 그리기
# 다변량 데이터로 다변량 그래프 그리기 - 산점도 그래프

# 1. 
def recode_sex(sex):
  if sex == 'Female':
    return 0
  else:
    return 1

# 2. recode_sex 함수가 반환한 값을 데이터 프레임에 열을 새로 생성하여 추가
# apply를 이용하여 sex 열에 recode_sex 함수를 브로드캐스팅
tips['sex_color'] = tips['sex'].apply(recode_sex)

# 3. scatter 메서드에 s,c 인잣값으로 테이블당 인원 수와 성별의 치환값을 전달
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size']*10,
    c = tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 04-3 seaborn 라이브러리 자유자재로 사용하기

# %%
# 단변량 그래프 그리기 - 히스토그램
# 1. 데이터 불러오기 및 패키지 import
import seaborn as sns

tips = sns.load_dataset("tips")

# 2. subplots, distplot을 이용하여 히스토그램 그리기
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')

# 3. distpot을 이용하여 히스토그램과 밀집도 그래프 그리기
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

# 4. 밀집도 그래프만 나타내려면 hist 인자를 False로 지정
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

# 5. 여러 그래프를 한 번에 출력하기
ax = plt.subplots( )
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')

# 6. count 그래프 그리기
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-11-09f65a43dc2d>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# <ipython-input-11-09f65a43dc2d>:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# ...

# %%
# 다양한 종류의 이변량 그래프 그리기
# 1. seaborn 라이브러리로 산점도 그래프 그리기

ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data = tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 2. jointplot을 이용해 산점도 그래프와 히스토그램 그리기
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 3. 육각 그래프는 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
# 4. kdeplot을 이용해 이차원 밀집도 그리기
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'],
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# <ipython-input-15-7edd82ef9b79>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(data=tips['total_bill'],
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7edd82ef9b79> in <module>
#       1 # 4. kdeplot을 이용해 이차원 밀집도 그리기
#       2 ax = plt.subplots()
# ----> 3 ax = sns.kdeplot(data=tips['total_bill'],
#       4                  data2=tips['tip'],
#       5                  shade=True)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1696
# ...

# %%
# 5. 바 그래프 그리기
ax = plt.subplots( )
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
# 6. 박스 그래프 그리기
ax = plt.subplots( )
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 7. 바이올린 그래프 그리기              
ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 8. 관계 그래프 그리기
fig = sns.pairplot(tips)

# %%
# 9. 8번의 그래프에서 중복 제외하고 그래프 그리기
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# 다변량 그래프 그리기
# 1. seaborn으로 바이올린 그래프 그리기
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 2. 산점도, 관계 그래프 그리기 - 색상 추가
scatter = sns.lmplot(x = 'total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips, hue='sex')

# %%
# 3. 산점도 그래프의 크기와 모양 조절하기
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', 
                     scatter_kws={'s':tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-557ab007426e> in <module>
#       1 # 3. 산점도 그래프의 크기와 모양 조절하기
# ----> 2 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
#       3                      scatter_kws={'s':tips['size']*10})
#       4
#
# /usr/local/lib/python3.9/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
# ...

# %%
# 4. markers를 이용하여 그래프의 점을 다른 기호로 표현하기
scatter = sns.lmplot(x='total_bill', y='tip',data=tips, fit_reg=False, hue='sex',
                     markers=['o','x'], scatter_kws={'s':tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5b00401a957a> in <module>
#       1 # 4. markers를 이용하여 그래프의 점을 다른 기호로 표현하기
# ----> 2 scatter = sns.lmplot(x='total_bill', y='tip',data=tips, fit_reg=False, hue='sex',
#       3                      markers=['o','x'], scatter_kws={'s':tips['size']*10})
#       4
#
# /usr/local/lib/python3.9/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     633         scatter_kws=scatter_kws, line_kws=line_kws,
#     634     )
# --> 635     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
# ...

# %%
# 5. lmplot을 이용해 데이터 그룹에 대한 그래프의 한 번에 그리기
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
# 6. col, col_warp를 이용하여 그래프 그리기
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                           col='dataset', col_wrap=2)

# %%
# FacetGrid 클래스로 그룹별 그래프 그리기
# 1. facet map로 그래프 그리기
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug = True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
# 2. 다변량 그래프 그리기
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

# %%
# 3. 더 많은 수의 변수를 사용해 그래프 그리기
facet = sns.FacetGrid(tips, col='time', row = 'smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# # 04-4 데이터프레임과 시리즈로 그래프 그리기

# %%
# 데이터프레임과 시리즈로 그래프 그리기

# 1. 히스토그램 그리기
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
# 2. 투명도 조절하기
fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
# 3. kde, scatter, hexbin 이용하여 그래프 그리기
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
# 4. gridsize를 이용해 육각 그래프 크기 조정하기
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
# 5. box 메서드를 이용해 박스 그래프
fig, ax = plt.subplots( ) 
ax = tips.plot.box(ax=ax)

# %% [markdown]
# # 04-5 seaborn 라이브러리로 그래프 스타일 설정하기

# %%
# 그래프에 스타일 적용하기
fig, ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 2. whitegrid로 그래프 배경 설정하기
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 3. for문을 이용해 모든 스타일을 하나씩 적용한 그래프 그리기
fig = plt.figure( )

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
